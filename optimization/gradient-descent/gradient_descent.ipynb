# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### hipotesis
# ![grad](img/gradient.png)
# ![grad](img/hipotesis.png)
# ### rumus pada gradient descent
# ![rumus](img/formula.png)
# ### theta untuk multi-atribut
# ![rumus](img/thetas.png)
# ###
# ![cara](img/first.png)
# ![cara](img/second.png)

# %%
#rumus cost function
def  cal_cost(theta,X,y):
    m = len(y)
    
    predictions = X.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

# %%
#rumus cost function
def gradient_descent(X,y,theta,learning_rate=0.01,iterations=100):
    m = len(y)
    
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    
    for it in range(iterations):    
        prediction = np.dot(X,theta)
        
        theta = theta -(1/m)*learning_rate*( X.T.dot((prediction - y)))
        theta_history[it,:] =theta.T
        cost_history[it]  = cal_cost(theta,X,y)
        print('no. {:d} - theta0: {:0.3f}, theta1: {:0.3f}, costfunc at thetas: {:0.3f}'.format(it+1,theta[0][0],theta[1][0],cost_history[it]))
        
    return theta, cost_history, theta_history

# %%
#make random data with theta0=4 and theta1=3
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X+np.random.randn(100,1)

# %%
plt.scatter(X, y,  color='#69cba1')
plt.show()

# %%
lr =0.01
n_iter = 1000

theta = np.random.randn(2,1)
print(theta)

X_b = np.c_[np.ones((len(X),1)),X]
theta,cost_history,theta_history = gradient_descent(X_b,y,theta,lr,n_iter)

print('theta0: {:0.3f},\ntheta1: {:0.3f}'.format(theta[0][0],theta[1][0]))
print('cost: {:0.3f}'.format(cost_history[-1]))
# Out:
# [[ 1.9797485 ]
#  [-0.85909837]]
# no. 1 - theta0: 2.036, theta1: -0.798, costfunc at thetas: 173738.123
# no. 2 - theta0: 2.091, theta1: -0.738, costfunc at thetas: 167199.039
# no. 3 - theta0: 2.145, theta1: -0.680, costfunc at thetas: 160912.357
# no. 4 - theta0: 2.198, theta1: -0.622, costfunc at thetas: 154868.332
# no. 5 - theta0: 2.250, theta1: -0.566, costfunc at thetas: 149057.593
# no. 6 - theta0: 2.301, theta1: -0.511, costfunc at thetas: 143471.136
# no. 7 - theta0: 2.351, theta1: -0.457, costfunc at thetas: 138100.301
# no. 8 - theta0: 2.400, theta1: -0.404, costfunc at thetas: 132936.763
# no. 9 - theta0: 2.447, theta1: -0.351, costfunc at thetas: 127972.518
# no. 10 - theta0: 2.494, theta1: -0.300, costfunc at thetas: 123199.873
# no. 11 - theta0: 2.540, theta1: -0.250, costfunc at thetas: 118611.430
# no. 12 - theta0: 2.585, theta1: -0.201, costfunc at thetas: 114200.077
# no. 13 - theta0: 2.630, theta1: -0.153, costfunc at thetas: 109958.978
# ...
